# %%
# !git clone https://github.com/RUCAIBox/RecBole.git
# Out:
# Cloning into 'RecBole'...
# remote: Enumerating objects: 23381, done.
# remote: Counting objects: 100% (3378/3378), done.
# remote: Compressing objects: 100% (306/306), done.
# remote: Total 23381 (delta 3159), reused 3072 (delta 3072), pack-reused 20003 (from 2)
# Receiving objects: 100% (23381/23381), 19.45 MiB | 30.13 MiB/s, done.
# Resolving deltas: 100% (15505/15505), done.

# %%
# %cd RecBole
# Out:
# /kaggle/working/RecBole

# %%
# !pip install -e . --verbose
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///kaggle/working/RecBole
#   Running command python setup.py egg_info
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for colorlog==4.7.2 from https://files.pythonhosted.org/packages/5e/39/0230290df0519d528d8d0ffdfd900150ed24e0076d13b1f19e279444aab1/colorlog-4.7.2-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for colorama==0.4.4 from https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for thop>=0.1.1.post2207130030 from https://files.pythonhosted.org/packages/bb/0f/72beeab4ff5221dc47127c80f8834b4bcd0cb36f6ba91c0b1d04a1233403/thop-0.1.1.post2209072238-py3-none-any.whl.metadata
# ...

# %%
import os
import torch
from torch.distributed import init_process_group, destroy_process_group
def ddp_setup(rank: int, world_size: int):
   """
   Args:
       rank: Unique identifier of each process
      world_size: Total number of processes
   """
   os.environ["MASTER_ADDR"] = "localhost"
   os.environ["MASTER_PORT"] = "12355"
   torch.cuda.set_device(rank)
   init_process_group(backend="nccl", rank=rank, world_size=world_size)

ddp_setup(0, 1)

# %%
# !wget -O 'dianping.zip' 'https://drive.usercontent.google.com/download?id=1rJEY2WuD42IFmRShuRU8Kbu5X3LbE29K&export=download&authuser=0&confirm=t&uuid=1b8cc49c-3cac-4e38-a033-8ebbaf0a6631&at=APvzH3ok2F08RK2ObuVXTodYXCed:1735290499244'
# Out:
# --2024-12-27 15:58:14--  https://drive.usercontent.google.com/download?id=1rJEY2WuD42IFmRShuRU8Kbu5X3LbE29K&export=download&authuser=0&confirm=t&uuid=1b8cc49c-3cac-4e38-a033-8ebbaf0a6631&at=APvzH3ok2F08RK2ObuVXTodYXCed:1735290499244
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 108.177.12.132, 2607:f8b0:400c:c08::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|108.177.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 374882520 (358M) [application/octet-stream]
# Saving to: ‘dianping.zip’
#
# dianping.zip        100%[===================>] 357.52M   176MB/s    in 2.0s
#
# 2024-12-27 15:58:18 (176 MB/s) - ‘dianping.zip’ saved [374882520/374882520]

# %%
# !unzip dianping.zip -d dataset
# Out:
# Archive:  dianping.zip
#  extracting: dataset/dianping/dianping.inter
#  extracting: dataset/dianping/dianping.item
#  extracting: dataset/dianping/dianping.kg
#  extracting: dataset/dianping/dianping.link
#  extracting: dataset/dianping/README.md

# %%
# %cd /kaggle/working/RecBole
# !python run_recbole.py --model='CKE' --dataset=dianping
# Out:
# /kaggle/working/RecBole
# 2024-12-27 15:58:26.136841: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-27 15:58:26.334539: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-27 15:58:26.390818: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Train     0:   0%|                                                         | 0/8724 [00:00<?, ?it/s]/kaggle/working/RecBole/recbole/trainer/trainer.py:235: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# ...
